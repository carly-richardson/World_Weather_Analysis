# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Step 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Step 4. Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests and JSON libraries.
import requests
import json

# Import the API key.
from config import weather_api_key

# %%
# Step 5. Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descr = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | zhigansk
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | lasa
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | awbari
# Processing Record 6 of Set 1 | constitucion
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | mount isa
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | waingapu
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | comodoro rivadavia
# Processing Record 21 of Set 1 | chute-aux-outardes
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | kaitong
# Processing Record 24 of Set 1 | ankang
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | itarema
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | nuuk
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | katete
# Processing Record 32 of Set 1 | kariba
# Processing Record 33 of Set 1 | coihaique
# Processing Record 34 of Set 1 | lata
# Processing Record 35 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | muroto
# Processing Record 38 of Set 1 | sao jose da coroa grande
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | alenquer
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | bijie
# Processing Record 45 of Set 1 | yandyki
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | arlit
# Processing Record 48 of Set 1 | leh
# Processing Record 49 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | taltal
# Processing Record 3 of Set 2 | erzin
# Processing Record 4 of Set 2 | minas de barroteran
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | thinadhoo
# Processing Record 10 of Set 2 | skjervoy
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | wanning
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | usinsk
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | yingzhong
# City not found. Skipping...
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | san andres
# Processing Record 20 of Set 2 | pangkalanbuun
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | gainesville
# Processing Record 23 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | sterling
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | sharkan
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | broken hill
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | cairns
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | aranda de duero
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | kang
# Processing Record 40 of Set 2 | saurimo
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | kattivakkam
# Processing Record 44 of Set 2 | te anau
# Processing Record 45 of Set 2 | yinchuan
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | taoudenni
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | tshela
# Processing Record 50 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | ouesso
# Processing Record 2 of Set 3 | zavyalovo
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | kapoeta
# Processing Record 5 of Set 3 | severomorsk
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | veliko gradiste
# Processing Record 11 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 3 | pahrump
# Processing Record 13 of Set 3 | hambantota
# Processing Record 14 of Set 3 | aberdeen
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | uvira
# Processing Record 18 of Set 3 | roald
# Processing Record 19 of Set 3 | samarai
# Processing Record 20 of Set 3 | aksarka
# Processing Record 21 of Set 3 | salta
# Processing Record 22 of Set 3 | loiza
# Processing Record 23 of Set 3 | kaili
# Processing Record 24 of Set 3 | bara
# Processing Record 25 of Set 3 | manzhouli
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | baran
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | aasiaat
# Processing Record 31 of Set 3 | yar-sale
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | salvador
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | magdalena
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | sur
# Processing Record 39 of Set 3 | quatre cocos
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | beaverlodge
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | bowen
# Processing Record 44 of Set 3 | mangaratiba
# Processing Record 45 of Set 3 | bahia blanca
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | kano
# Processing Record 48 of Set 3 | tahta
# Processing Record 49 of Set 3 | terrace
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | lazaro cardenas
# Processing Record 5 of Set 4 | changping
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | balkanabat
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | nouakchott
# Processing Record 10 of Set 4 | gravdal
# Processing Record 11 of Set 4 | gamba
# Processing Record 12 of Set 4 | vanimo
# Processing Record 13 of Set 4 | moose jaw
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | tual
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | ushumun
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | puri
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | takapau
# Processing Record 26 of Set 4 | kamaishi
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | escanaba
# Processing Record 29 of Set 4 | tabou
# Processing Record 30 of Set 4 | chicama
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | san quintin
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | kudahuvadhoo
# Processing Record 36 of Set 4 | paamiut
# Processing Record 37 of Set 4 | acarau
# Processing Record 38 of Set 4 | codrington
# Processing Record 39 of Set 4 | tallahassee
# Processing Record 40 of Set 4 | ambon
# Processing Record 41 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | zandak
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | hornepayne
# Processing Record 47 of Set 4 | vila velha
# Processing Record 48 of Set 4 | concarneau
# Processing Record 49 of Set 4 | kholtoson
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | muravlenko
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 5 | maningrida
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | dongfeng
# Processing Record 7 of Set 5 | papara
# Processing Record 8 of Set 5 | carutapera
# Processing Record 9 of Set 5 | praia da vitoria
# Processing Record 10 of Set 5 | coria
# Processing Record 11 of Set 5 | bucerias
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | swellendam
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | odesskoye
# Processing Record 16 of Set 5 | sosva
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | birao
# Processing Record 22 of Set 5 | estevan
# Processing Record 23 of Set 5 | darlowo
# Processing Record 24 of Set 5 | milkovo
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | kingaroy
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | solnechnyy
# Processing Record 29 of Set 5 | ghanzi
# Processing Record 30 of Set 5 | bodajk
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | vardo
# Processing Record 35 of Set 5 | ternate
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | deneysville
# Processing Record 38 of Set 5 | asau
# Processing Record 39 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 5 | altamira
# Processing Record 41 of Set 5 | westport
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | high prairie
# Processing Record 44 of Set 5 | qaqortoq
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | bakchar
# Processing Record 48 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | diu
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | ola
# Processing Record 3 of Set 6 | saint-augustin
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | namtsy
# Processing Record 6 of Set 6 | ewa beach
# Processing Record 7 of Set 6 | naica
# Processing Record 8 of Set 6 | svetlyy
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | abha
# Processing Record 11 of Set 6 | obidos
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | sambava
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | moosomin
# Processing Record 16 of Set 6 | tamandare
# Processing Record 17 of Set 6 | severnoye
# Processing Record 18 of Set 6 | keetmanshoop
# Processing Record 19 of Set 6 | nelson bay
# Processing Record 20 of Set 6 | lexington
# Processing Record 21 of Set 6 | holoby
# Processing Record 22 of Set 6 | honningsvag
# Processing Record 23 of Set 6 | opuwo
# Processing Record 24 of Set 6 | cayenne
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | tilichiki
# Processing Record 27 of Set 6 | nouadhibou
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | iwanai
# Processing Record 30 of Set 6 | hualmay
# Processing Record 31 of Set 6 | saint-joseph
# Processing Record 32 of Set 6 | saint anthony
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | vitina
# Processing Record 35 of Set 6 | beira
# Processing Record 36 of Set 6 | fortuna
# Processing Record 37 of Set 6 | kushnarenkovo
# Processing Record 38 of Set 6 | san rafael del sur
# Processing Record 39 of Set 6 | muros
# Processing Record 40 of Set 6 | glenwood springs
# Processing Record 41 of Set 6 | nome
# Processing Record 42 of Set 6 | paita
# Processing Record 43 of Set 6 | sistranda
# Processing Record 44 of Set 6 | barrow
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | olafsvik
# Processing Record 47 of Set 6 | vicuna
# Processing Record 48 of Set 6 | kalach-na-donu
# Processing Record 49 of Set 6 | huejuquilla el alto
# Processing Record 50 of Set 6 | yulara
# Processing Record 1 of Set 7 | tazmalt
# Processing Record 2 of Set 7 | owase
# Processing Record 3 of Set 7 | robertsport
# Processing Record 4 of Set 7 | mangan
# Processing Record 5 of Set 7 | huarmey
# Processing Record 6 of Set 7 | puerto quijarro
# Processing Record 7 of Set 7 | conop
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | lichuan
# Processing Record 10 of Set 7 | lira
# Processing Record 11 of Set 7 | noumea
# Processing Record 12 of Set 7 | linxia
# Processing Record 13 of Set 7 | chilca
# Processing Record 14 of Set 7 | sabya
# Processing Record 15 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 7 | warri
# Processing Record 18 of Set 7 | kavieng
# Processing Record 19 of Set 7 | goderich
# Processing Record 20 of Set 7 | panjab
# Processing Record 21 of Set 7 | northam
# Processing Record 22 of Set 7 | weligama
# Processing Record 23 of Set 7 | puerto escondido
# Processing Record 24 of Set 7 | birur
# Processing Record 25 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | itoman
# Processing Record 28 of Set 7 | hoopstad
# Processing Record 29 of Set 7 | meadow lake
# Processing Record 30 of Set 7 | pokaran
# Processing Record 31 of Set 7 | ahuimanu
# Processing Record 32 of Set 7 | yatou
# Processing Record 33 of Set 7 | innisfail
# Processing Record 34 of Set 7 | saldanha
# Processing Record 35 of Set 7 | lanzhou
# Processing Record 36 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 7 | rabo de peixe
# Processing Record 38 of Set 7 | shkotovo-26
# City not found. Skipping...
# Processing Record 39 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 7 | talnakh
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | teknaf
# Processing Record 44 of Set 7 | taikang
# Processing Record 45 of Set 7 | kursenai
# Processing Record 46 of Set 7 | omboue
# Processing Record 47 of Set 7 | kormilovka
# Processing Record 48 of Set 7 | palampur
# Processing Record 49 of Set 7 | panzhihua
# Processing Record 50 of Set 7 | bogale
# Processing Record 1 of Set 8 | praia
# Processing Record 2 of Set 8 | sinegorye
# Processing Record 3 of Set 8 | key west
# Processing Record 4 of Set 8 | cabo san lucas
# Processing Record 5 of Set 8 | arraial do cabo
# Processing Record 6 of Set 8 | dedza
# Processing Record 7 of Set 8 | chapais
# Processing Record 8 of Set 8 | bajil
# Processing Record 9 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 10 of Set 8 | ilo
# Processing Record 11 of Set 8 | yate
# Processing Record 12 of Set 8 | iglesias
# Processing Record 13 of Set 8 | bagli
# Processing Record 14 of Set 8 | russell
# Processing Record 15 of Set 8 | raga
# Processing Record 16 of Set 8 | grimshaw
# Processing Record 17 of Set 8 | luanda
# Processing Record 18 of Set 8 | turukhansk
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | hami
# Processing Record 21 of Set 8 | milford
# Processing Record 22 of Set 8 | beloha
# Processing Record 23 of Set 8 | jalu
# Processing Record 24 of Set 8 | zhuanghe
# Processing Record 25 of Set 8 | salinas
# Processing Record 26 of Set 8 | vao
# Processing Record 27 of Set 8 | alta floresta
# Processing Record 28 of Set 8 | keti bandar
# Processing Record 29 of Set 8 | tuatapere
# Processing Record 30 of Set 8 | maputo
# Processing Record 31 of Set 8 | safranbolu
# Processing Record 32 of Set 8 | seymchan
# Processing Record 33 of Set 8 | ferrol
# Processing Record 34 of Set 8 | hamadan
# Processing Record 35 of Set 8 | hobyo
# Processing Record 36 of Set 8 | san carlos de bariloche
# Processing Record 37 of Set 8 | vila franca do campo
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | panaba
# Processing Record 40 of Set 8 | ihosy
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | inhambane
# Processing Record 43 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | tokur
# Processing Record 46 of Set 8 | xuddur
# Processing Record 47 of Set 8 | adre
# Processing Record 48 of Set 8 | takab
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | acapulco
# Processing Record 1 of Set 9 | leshukonskoye
# Processing Record 2 of Set 9 | mehamn
# Processing Record 3 of Set 9 | shingu
# Processing Record 4 of Set 9 | presidencia roque saenz pena
# Processing Record 5 of Set 9 | navirai
# Processing Record 6 of Set 9 | khadro
# Processing Record 7 of Set 9 | neuquen
# Processing Record 8 of Set 9 | yarmouth
# Processing Record 9 of Set 9 | tashigang
# Processing Record 10 of Set 9 | okhotsk
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | san jeronimo
# Processing Record 13 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | egvekinot
# Processing Record 15 of Set 9 | antofagasta
# Processing Record 16 of Set 9 | bay roberts
# Processing Record 17 of Set 9 | mount vernon
# Processing Record 18 of Set 9 | pontian kecil
# Processing Record 19 of Set 9 | chipinge
# Processing Record 20 of Set 9 | mount gambier
# Processing Record 21 of Set 9 | brae
# Processing Record 22 of Set 9 | kirovsk
# Processing Record 23 of Set 9 | tessalit
# Processing Record 24 of Set 9 | lapas
# Processing Record 25 of Set 9 | bathurst
# Processing Record 26 of Set 9 | nizhnevartovsk
# Processing Record 27 of Set 9 | kavaratti
# Processing Record 28 of Set 9 | sulangan
# Processing Record 29 of Set 9 | betanzos
# Processing Record 30 of Set 9 | tamiahua
# Processing Record 31 of Set 9 | carnarvon
# Processing Record 32 of Set 9 | tigil
# Processing Record 33 of Set 9 | nuevo progreso
# Processing Record 34 of Set 9 | ust-omchug
# Processing Record 35 of Set 9 | scarborough
# Processing Record 36 of Set 9 | vestmanna
# Processing Record 37 of Set 9 | batemans bay
# Processing Record 38 of Set 9 | nara
# Processing Record 39 of Set 9 | floro
# Processing Record 40 of Set 9 | sisimiut
# Processing Record 41 of Set 9 | labuhan
# Processing Record 42 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 9 | hailar
# Processing Record 44 of Set 9 | urengoy
# Processing Record 45 of Set 9 | meulaboh
# Processing Record 46 of Set 9 | santa ana
# Processing Record 47 of Set 9 | shache
# Processing Record 48 of Set 9 | rauma
# Processing Record 49 of Set 9 | price
# Processing Record 50 of Set 9 | axim
# Processing Record 1 of Set 10 | san ramon
# Processing Record 2 of Set 10 | bermejillo
# Processing Record 3 of Set 10 | junction city
# Processing Record 4 of Set 10 | quang ngai
# Processing Record 5 of Set 10 | rawson
# Processing Record 6 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 10 | celestun
# Processing Record 8 of Set 10 | san juan
# Processing Record 9 of Set 10 | kifri
# Processing Record 10 of Set 10 | roma
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | tumut
# Processing Record 13 of Set 10 | palu
# Processing Record 14 of Set 10 | wilmington
# Processing Record 15 of Set 10 | umea
# Processing Record 16 of Set 10 | horsham
# Processing Record 17 of Set 10 | palmer
# Processing Record 18 of Set 10 | aksu
# Processing Record 19 of Set 10 | wenatchee
# Processing Record 20 of Set 10 | aswan
# Processing Record 21 of Set 10 | xichang
# Processing Record 22 of Set 10 | sao joao da barra
# Processing Record 23 of Set 10 | llanes
# Processing Record 24 of Set 10 | kristiansund
# Processing Record 25 of Set 10 | komsomolskiy
# Processing Record 26 of Set 10 | nijar
# Processing Record 27 of Set 10 | sorong
# Processing Record 28 of Set 10 | kloulklubed
# Processing Record 29 of Set 10 | nizhniy kuranakh
# Processing Record 30 of Set 10 | teguldet
# Processing Record 31 of Set 10 | sile
# Processing Record 32 of Set 10 | bambanglipuro
# Processing Record 33 of Set 10 | machico
# Processing Record 34 of Set 10 | iracoubo
# Processing Record 35 of Set 10 | ixtapa
# Processing Record 36 of Set 10 | grand-lahou
# Processing Record 37 of Set 10 | fare
# Processing Record 38 of Set 10 | rio gallegos
# Processing Record 39 of Set 10 | san cristobal
# Processing Record 40 of Set 10 | nkan
# Processing Record 41 of Set 10 | solana beach
# Processing Record 42 of Set 10 | takoradi
# Processing Record 43 of Set 10 | pljevlja
# Processing Record 44 of Set 10 | pestravka
# Processing Record 45 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 10 | ucluelet
# Processing Record 47 of Set 10 | katesh
# Processing Record 48 of Set 10 | ekhabi
# Processing Record 49 of Set 10 | paine
# Processing Record 50 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 1 of Set 11 | atar
# Processing Record 2 of Set 11 | morgan city
# Processing Record 3 of Set 11 | liverpool
# Processing Record 4 of Set 11 | riwaka
# Processing Record 5 of Set 11 | cuiluan
# Processing Record 6 of Set 11 | mikuni
# Processing Record 7 of Set 11 | nelson
# Processing Record 8 of Set 11 | rio verde de mato grosso
# Processing Record 9 of Set 11 | salalah
# Processing Record 10 of Set 11 | la paz
# Processing Record 11 of Set 11 | kailua
# Processing Record 12 of Set 11 | oktyabrskoye
# Processing Record 13 of Set 11 | shouguang
# Processing Record 14 of Set 11 | jos
# Processing Record 15 of Set 11 | alexandria
# Processing Record 16 of Set 11 | guane
# Processing Record 17 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | la massana
# Processing Record 21 of Set 11 | kasongo-lunda
# Processing Record 22 of Set 11 | suoyarvi
# Processing Record 23 of Set 11 | ubon ratchathani
# Processing Record 24 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 11 | penzance
# Processing Record 26 of Set 11 | camopi
# Processing Record 27 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 28 of Set 11 | sweetwater
# Processing Record 29 of Set 11 | vuktyl
# Processing Record 30 of Set 11 | sinop
# Processing Record 31 of Set 11 | bonavista
# Processing Record 32 of Set 11 | imbituba
# Processing Record 33 of Set 11 | nantucket
# Processing Record 34 of Set 11 | netarhat
# Processing Record 35 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 11 | newport
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | sfantu gheorghe
# Processing Record 39 of Set 11 | hofn
# Processing Record 40 of Set 11 | kutum
# Processing Record 41 of Set 11 | sena madureira
# Processing Record 42 of Set 11 | adana
# Processing Record 43 of Set 11 | coquimbo
# Processing Record 44 of Set 11 | sola
# Processing Record 45 of Set 11 | beyla
# Processing Record 46 of Set 11 | dangriga
# Processing Record 47 of Set 11 | novaya igirma
# Processing Record 48 of Set 11 | poya
# Processing Record 49 of Set 11 | andenes
# Processing Record 50 of Set 11 | tynda
# Processing Record 1 of Set 12 | srednekolymsk
# Processing Record 2 of Set 12 | mzimba
# Processing Record 3 of Set 12 | aklavik
# Processing Record 4 of Set 12 | porto novo
# Processing Record 5 of Set 12 | loughrea
# Processing Record 6 of Set 12 | tabuk
# Processing Record 7 of Set 12 | kholm-zhirkovskiy
# Processing Record 8 of Set 12 | sept-iles
# Processing Record 9 of Set 12 | nueva imperial
# Processing Record 10 of Set 12 | palaiokhora
# City not found. Skipping...
# Processing Record 11 of Set 12 | bereda
# Processing Record 12 of Set 12 | lodja
# Processing Record 13 of Set 12 | clyde river
# Processing Record 14 of Set 12 | camana
# Processing Record 15 of Set 12 | kedrovyy
# Processing Record 16 of Set 12 | kilakarai
# Processing Record 17 of Set 12 | mareeba
# Processing Record 18 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 12 | kidal
# Processing Record 20 of Set 12 | zverinogolovskoye
# Processing Record 21 of Set 12 | kodinsk
# Processing Record 22 of Set 12 | namatanai
# Processing Record 23 of Set 12 | ornskoldsvik
# Processing Record 24 of Set 12 | juba
# Processing Record 25 of Set 12 | aripuana
# Processing Record 26 of Set 12 | sosnovo-ozerskoye
# Processing Record 27 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 12 | krasnoselkup
# Processing Record 29 of Set 12 | lampang
# Processing Record 30 of Set 12 | matamoros
# Processing Record 31 of Set 12 | domoni
# Processing Record 32 of Set 12 | touros
# Processing Record 33 of Set 12 | clinton
# Processing Record 34 of Set 12 | jibuti
# Processing Record 35 of Set 12 | margate
# Processing Record 36 of Set 12 | kopidlno
# Processing Record 37 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | kirakira
# Processing Record 40 of Set 12 | irece
# Processing Record 41 of Set 12 | maryborough
# Processing Record 42 of Set 12 | porto walter
# Processing Record 43 of Set 12 | tagusao
# Processing Record 44 of Set 12 | lesozavodsk
# Processing Record 45 of Set 12 | santa cruz
# Processing Record 46 of Set 12 | champerico
# Processing Record 47 of Set 12 | ayios vasilios
# Processing Record 48 of Set 12 | buchanan
# Processing Record 49 of Set 12 | natal
# Processing Record 50 of Set 12 | basco
# Processing Record 1 of Set 13 | ballyhaunis
# Processing Record 2 of Set 13 | svetlogorsk
# Processing Record 3 of Set 13 | koulikoro
# Processing Record 4 of Set 13 | sidi ali
# Processing Record 5 of Set 13 | tabriz
# Processing Record 6 of Set 13 | kahului
# Processing Record 7 of Set 13 | redcliffe
# Processing Record 8 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 13 | el balyana
# City not found. Skipping...
# Processing Record 10 of Set 13 | walvis bay
# Processing Record 11 of Set 13 | sinnamary
# Processing Record 12 of Set 13 | little current
# Processing Record 13 of Set 13 | rockport
# Processing Record 14 of Set 13 | tongren
# Processing Record 15 of Set 13 | banda aceh
# Processing Record 16 of Set 13 | zhezkazgan
# Processing Record 17 of Set 13 | romny
# Processing Record 18 of Set 13 | lac-megantic
# Processing Record 19 of Set 13 | nyeri
# Processing Record 20 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 13 | chifeng
# Processing Record 22 of Set 13 | shahr-e kord
# Processing Record 23 of Set 13 | waddan
# Processing Record 24 of Set 13 | cambuci
# Processing Record 25 of Set 13 | shumyachi
# Processing Record 26 of Set 13 | corrales
# Processing Record 27 of Set 13 | karhal
# Processing Record 28 of Set 13 | parabel
# Processing Record 29 of Set 13 | barentu
# Processing Record 30 of Set 13 | vostok
# Processing Record 31 of Set 13 | karwar
# Processing Record 32 of Set 13 | filingue
# Processing Record 33 of Set 13 | alihe
# Processing Record 34 of Set 13 | joshimath
# Processing Record 35 of Set 13 | oudtshoorn
# Processing Record 36 of Set 13 | caravelas
# Processing Record 37 of Set 13 | grindavik
# Processing Record 38 of Set 13 | palmas
# Processing Record 39 of Set 13 | arroyo
# Processing Record 40 of Set 13 | haverfordwest
# Processing Record 41 of Set 13 | ha giang
# Processing Record 42 of Set 13 | colchester
# Processing Record 43 of Set 13 | kokopo
# Processing Record 44 of Set 13 | kangaatsiaq
# Processing Record 45 of Set 13 | oneonta
# Processing Record 46 of Set 13 | nykoping
# Processing Record 47 of Set 13 | flinders
# Processing Record 48 of Set 13 | moron
# Processing Record 49 of Set 13 | amga
# Processing Record 50 of Set 13 | pundaguitan
# Processing Record 1 of Set 14 | elizabeth city
# Processing Record 2 of Set 14 | eyl
# Processing Record 3 of Set 14 | harper
# Processing Record 4 of Set 14 | yelandur
# Processing Record 5 of Set 14 | fairhope
# Processing Record 6 of Set 14 | khandyga
# Processing Record 7 of Set 14 | fukuma
# Processing Record 8 of Set 14 | damietta
# Processing Record 9 of Set 14 | mayo
# Processing Record 10 of Set 14 | ntungamo
# Processing Record 11 of Set 14 | bafoulabe
# Processing Record 12 of Set 14 | ibotirama
# Processing Record 13 of Set 14 | helena
# Processing Record 14 of Set 14 | kolpashevo
# Processing Record 15 of Set 14 | biak
# Processing Record 16 of Set 14 | santiago del estero
# Processing Record 17 of Set 14 | mpika
# Processing Record 18 of Set 14 | tevaitoa
# Processing Record 19 of Set 14 | bachaquero
# Processing Record 20 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 14 | huamuxtitlan
# Processing Record 22 of Set 14 | manggar
# Processing Record 23 of Set 14 | zhanakorgan
# Processing Record 24 of Set 14 | vagur
# Processing Record 25 of Set 14 | bud
# Processing Record 26 of Set 14 | onguday
# Processing Record 27 of Set 14 | guanica
# Processing Record 28 of Set 14 | murgab
# Processing Record 29 of Set 14 | mocuba
# Processing Record 30 of Set 14 | itanagar
# Processing Record 31 of Set 14 | capaccio
# Processing Record 32 of Set 14 | zyryanka
# Processing Record 33 of Set 14 | erenhot
# Processing Record 34 of Set 14 | chinchani
# Processing Record 35 of Set 14 | lichinga
# Processing Record 36 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 37 of Set 14 | saint-georges
# Processing Record 38 of Set 14 | oskemen
# Processing Record 39 of Set 14 | rjukan
# Processing Record 40 of Set 14 | kabinda
# Processing Record 41 of Set 14 | nishihara
# Processing Record 42 of Set 14 | arica
# Processing Record 43 of Set 14 | iramuco
# Processing Record 44 of Set 14 | jimo
# Processing Record 45 of Set 14 | havoysund
# Processing Record 46 of Set 14 | zeya
# Processing Record 47 of Set 14 | kenai
# Processing Record 48 of Set 14 | kondopoga
# Processing Record 49 of Set 14 | makubetsu
# Processing Record 50 of Set 14 | morwa
# Processing Record 1 of Set 15 | alyangula
# Processing Record 2 of Set 15 | imeni poliny osipenko
# Processing Record 3 of Set 15 | susanville
# Processing Record 4 of Set 15 | lagoa
# Processing Record 5 of Set 15 | quelimane
# Processing Record 6 of Set 15 | zabol
# Processing Record 7 of Set 15 | biga
# Processing Record 8 of Set 15 | iquitos
# Processing Record 9 of Set 15 | gizo
# Processing Record 10 of Set 15 | itacare
# Processing Record 11 of Set 15 | ereymentau
# Processing Record 12 of Set 15 | ulladulla
# Processing Record 13 of Set 15 | kohima
# Processing Record 14 of Set 15 | boa vista
# Processing Record 15 of Set 15 | dunn
# Processing Record 16 of Set 15 | telemaco borba
# Processing Record 17 of Set 15 | kaniama
# Processing Record 18 of Set 15 | mufulira
# Processing Record 19 of Set 15 | goure
# Processing Record 20 of Set 15 | khasan
# Processing Record 21 of Set 15 | zarubino
# Processing Record 22 of Set 15 | adilcevaz
# Processing Record 23 of Set 15 | jolalpan
# Processing Record 24 of Set 15 | sokoni
# Processing Record 25 of Set 15 | ust-kuyga
# Processing Record 26 of Set 15 | tyssedal
# Processing Record 27 of Set 15 | marsh harbour
# Processing Record 28 of Set 15 | teahupoo
# Processing Record 29 of Set 15 | ust-kulom
# Processing Record 30 of Set 15 | hokitika
# Processing Record 31 of Set 15 | fairbanks
# Processing Record 32 of Set 15 | manakara
# Processing Record 33 of Set 15 | shimoda
# Processing Record 34 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 36 of Set 15 | santa helena de goias
# Processing Record 37 of Set 15 | nagaur
# Processing Record 38 of Set 15 | dasoguz
# Processing Record 39 of Set 15 | lucapa
# Processing Record 40 of Set 15 | tambacounda
# Processing Record 41 of Set 15 | farmington
# Processing Record 42 of Set 15 | belmonte
# Processing Record 43 of Set 15 | muli
# Processing Record 44 of Set 15 | baleshwar
# Processing Record 45 of Set 15 | iguape
# Processing Record 46 of Set 15 | severnyy
# Processing Record 47 of Set 15 | weihai
# Processing Record 48 of Set 15 | of
# City not found. Skipping...
# Processing Record 49 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 15 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Zhigansk      RU  66.7697  123.3711     -1.71       100          87
# 1      Katsuura      JP  35.1333  140.3000     55.78        63          99
# 2          Lasa      IT  46.6166   10.7002     45.48        90          39
# 3    Butaritari      KI   3.0707  172.7902     81.30        78          29
# 4        Awbari      LY  26.5921   12.7805     68.29        29           0
# 5  Constitucion      CL -35.3333  -72.4167     57.43        73           4
# 6         Tiksi      RU  71.6872  128.8694     -7.42        97          60
# 7  Port Lincoln      AU -34.7333  135.8667     64.94        88         100
# 8   Tuktoyaktuk      CA  69.4541 -133.0374      1.40        66          20
# 9         Kapaa      US  22.0752 -159.3190     80.58        83          20
#
#    Wind Speed Current Description
# 0        8.25     overcast clouds
# 1        9.82     overcast clouds
# 2        6.87    scattered clouds
# 3       14.32    scattered clouds
# 4       15.99           clear sky
# 5        7.29           clear sky
# 6        4.36       broken clouds
# 7        9.62     overcast clouds
# 8        5.75          few clouds
# 9       18.41          few clouds

# %%
# Step 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the WeatherDatabase folder.
# Create the output file (csv).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
